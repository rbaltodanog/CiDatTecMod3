# %% [markdown]
# # Examen - Estadística para Ciencia de los Datos
# ## 125 puntos
#
# Responda las siguientes preguntas de manera individual y con el mayor nivel de detalle posible. Donde corresponda, aparte de su justificación, muestre todos los cálculos utilizados para encontrar la solución.
#
#
# 1. ¿Cuál es la diferencia entre una función de densidad de probabilidad y una función de distribución de probabilidad acumulativa? Utilice un gráfico ilustrativo para la explicación. ¿Cuándo queremos usar una o la otra? ¿En el caso discreto, cuál es la diferencia en la interpretación del valor retornado por cada una de las dos funciones para la misma entrada $x_i$? **10 puntos**
#
# 2. A lo largo del curso utilizamos diferentes nomenclaturas para la media y desviación estándar. ¿Cuál es la diferencia entre $\mu$ y $\bar{x}$? ¿Cuál es la diferencia entre $\sigma$ y $s$? ¿En qué casos concretos se utilizan unas versus las otras? **10 puntos**
#
#
# 3. La prueba de normalidad KS vista en clase no solamente se limita a probar si una distribución es normal. Se puede utilizar para probar si un conjunto de datos proviene de cualquier otra distribución de probabilidad. ¿Es esta afirmación correcta? ¿Por qué sí o por qué no? De argumentos suficientes, con ejemplos de ser posible de por qué su respuesta es afirmativa o negativa. **5 puntos**
#
#
# 4. Asuma que se tiene una moneda de 500 colones mágica que, al tirarla al aire, cae en escudo el doble de las veces que cae en corona.
#   - ¿Cuál es la probabilidad de tirar la moneda 3 veces y que caiga corona 3 veces? **3 puntos**
#   - ¿Cuál es la probabilidad de tirar la moneda 4 veces y que caiga escudo 4 veces? **2 puntos**
#   - ¿Cuál es el $\mu$ y $\sigma^2$ de la variable aleatoria que modela este fenómeno, asumiendo que se tienen 25 repeticiones? **5 puntos**
#   - ¿Cuál sería la probabilidad de obtener 24 escudos y una corona? **5 puntos**
#
#
# 5.  Suponga que tenemos máquinas que colocan botones en camisas de manera automatizada, pero sufren de un cierto nivel de error al colocar dichos botones. Asumimos que la desviación estándar del error de la colocación de botones es 0.015 milímetros.
#   - El fabricante de las máquinas afirma que el error medio es menor a $\mu=0.3$ milímetros. Una muestra aleatoria de 75 observaciones indica que que se tiene un error promedio de 0.31 milímetros. ¿Es correcta la afirmación del fabricante? Use un nivel de significancia  de 0.01. **7 puntos**
#   - Si quisieramos construir un intervalo de confianza para la media del error $\mu$ ¿De qué tamaño debe ser la muestra si deseamos tener un nivel de confianza del 95% de que la media poblacional esté dentro del rango de 0.001 milímetros alrededor de la media muestral? **3 puntos**
#
#
# 6. Bajo el contexto de prueba de hipótesis, explique en que consiste cada tipo de error. Adicionalmente, explique que representan $\alpha$ y $\beta$ y como pueden reducirse. **10 puntos**
#
# 7. El número de colonias de cierto tipo de bacterias en muestras de agua contaminada tiene una distribución de Poisson con una media de 2 por centímetro cúbico ($cm^3$). Si cuatro muestras de 1 $cm^3$ se seleccionan de esta agua de manera independiente, encuentre la probabilidad de que al menos una contenga una o más colonias de bacterias **10 puntos**
#
# 8. ¿Qué efecto tiene el tamaño de la muestra $n$ en la distribución de $\overline{x}$? Mencione al menos un factor más que influye en la distribución de $\overline{x}$. **5 puntos**
#
# 9. ¿Qué quiere decir que dos variables aleatorias son independientes y cómo se expresa matemáticamente? En el contexto de un conjunto de datos utilizados para entrenar un modelo, ¿Es preferible que las características (features) usadas sean dependientes entre sí o independientes? Explique. **5 puntos**
#
# 10. Si se tienen 2 eventos $C$ y $D$ con probabilidades $p_C$ y $p_D$ ¿Cuál es la probabilidad máxima de que no ocurra $D$ o que ocurra $C$, en términos de sus probabilidades individuales? **5 puntos**
#
# 11. ¿Cuáles fueron las medidas de tendencia central vistas en clase? ¿En qué consiste cada una? y ¿En qué casos es útil usar cada una? **10 puntos**
#
# 12. Explique: ¿Qué es $SS_{T}$ en el contexto de ANOVA? ¿Cuáles son sus componentes y qué significado tiene cada uno? ¿Qué son y que relación tiene $\textrm{MS}_\textrm{tratamiento}$ y $\textrm{MS}_\textrm{error}$ con la hipótesis nula planteada en el ANOVA? **10 puntos**
#
# 13. Suponga que tenemos dos variables aleatorias $X_1$ y $X_2$ que representan la cantidad de vallas publicitarias compradas en la autopista Florencio de Castillo y el volumen de ventas por semana, respectivamente. Calcule la matriz de covarianza y la matriz de correlación de Pearson para una muestra a lo largo de 10 semanas con los siguientes datos: **20 puntos**
#
#   - $h_1 = [2, 5, 1, 3, 4, 1, 5, 3, 4, 2]$
#   - $h_2 = [50, 57, 41, 54, 54, 38, 63, 48, 59, 46] $

# %% [markdown]
# ![](https://drive.google.com/uc?id=1cnfEWyM-0YaFKwaSvk4IQzCEODkbvx3J)
